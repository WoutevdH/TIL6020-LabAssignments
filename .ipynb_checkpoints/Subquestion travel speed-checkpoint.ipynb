# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set_theme(style="darkgrid")

# %%
path = r"CBS.csv"

data = pd.read_csv(path,sep=';',skiprows=[0, 1, 2, 3 ],header=[0, 1, 2],index_col=[0])
data = data.replace(',', '.', regex=True)

data = data.dropna(thresh=data.shape[1] - 1)
data = data.drop('Unnamed: 1_level_0',axis=1,level=0)
data.index = data.index.str.replace('*', '', regex=False)
display(data)
# Out:
#                                    Vervoerwijzen  \
#                                        Onderwerp
# Perioden                            Reismotieven
# 1999                                      Totaal
# 1999                        Van en naar het werk
# 1999                 Winkelen. boodschappen doen
# 1999      Onderwijs volgen. cursus. kinderopvang
# 1999                                  Vrije tijd
# ...                                          ...
# 2019                        Van en naar het werk
# 2019                 Winkelen. boodschappen doen
# 2019      Onderwijs volgen. cursus. kinderopvang
# 2019                                  Vrije tijd
# 2019                        Overige reismotieven
#
#                                          Totaal  \
#          Ritten per persoon per dag (gemiddeld)
# Perioden                                 aantal
# 1999                                       3.41
# 1999                                       0.59
# 1999                                       0.73
# 1999                                        0.3
# 1999                                       1.19
# ...                                         ...
# 2019                                       0.61
# 2019                                       0.57
# 2019                                       0.28
# 2019                                       1.05
# 2019                                       0.45
#
#                                                                  \
#          Afgelegde afstand per rit (gemiddeld) Reisduur per rit
# Perioden                                    km          Minuten
# 1999                                     10.96            23.72
# 1999                                     14.78            24.83
# 1999                                      4.96            14.97
# 1999                                      6.85            17.64
# 1999                                     12.42            31.37
# ...                                        ...              ...
# 2019                                     16.13            24.83
# 2019                                      5.36            14.35
# 2019                                      7.28            18.58
# 2019                                      13.5            32.59
# 2019                                     11.87            19.57
#
#                               Auto (bestuurder)  \
#          Ritten per persoon per dag (gemiddeld)
# Perioden                                 aantal
# 1999                                       1.06
# 1999                                       0.23
# 1999                                       0.23
# 1999                                       0.02
# 1999                                       0.31
# ...                                         ...
# 2019                                       0.25
# 2019                                        0.2
# 2019                                       0.01
# 2019                                       0.26
# 2019                                       0.21
#
#                                                                  \
#          Afgelegde afstand per rit (gemiddeld) Reisduur per rit
# Perioden                                    km          Minuten
# 1999                                     16.16            23.91
# 1999                                     20.62            28.76
# 1999                                      6.94            14.57
# 1999                                     21.61            25.68
# 1999                                     18.15             27.9
# ...                                        ...              ...
# 2019                                     24.99            30.38
# 2019                                      7.78            14.86
# 2019                                     26.09            33.31
# 2019                                     22.07            29.47
# 2019                                     16.31            22.08
#
#                                Auto (passagier)  \
#          Ritten per persoon per dag (gemiddeld)
# Perioden                                 aantal
# 1999                                       0.48
# 1999                                       0.05
# 1999                                       0.09
# 1999                                       0.03
# 1999                                       0.25
# ...                                         ...
# 2019                                       0.02
# 2019                                       0.06
# 2019                                       0.02
# 2019                                       0.18
# 2019                                       0.05
#
#                                                                  ...  \
#          Afgelegde afstand per rit (gemiddeld) Reisduur per rit  ...
# Perioden                                    km          Minuten  ...
# 1999                                     19.04            28.42  ...
# 1999                                        21            31.52  ...
# 1999                                      9.99            19.11  ...
# 1999                                      8.84            17.26  ...
# 1999                                     21.47            32.46  ...
# ...                                        ...              ...  ...
# 2019                                     21.43            28.94  ...
# 2019                                     11.65            19.34  ...
# 2019                                      8.11            16.54  ...
# 2019                                     25.03            32.44  ...
# 2019                                     18.76            25.47  ...
#
#            Bus/tram/metro                                  Fiets  \
#          Reisduur per rit Ritten per persoon per dag (gemiddeld)
# Perioden          Minuten                                 aantal
# 1999                27.45                                   0.87
# 1999                25.63                                   0.15
# 1999                25.27                                    0.2
# 1999                27.43                                   0.12
# 1999                31.66                                   0.27
# ...                   ...                                    ...
# 2019                24.49                                   0.16
# 2019                 23.8                                   0.16
# 2019                26.89                                   0.13
# 2019                28.53                                   0.27
# 2019                25.18                                    0.1
#
#                                                                  \
#          Afgelegde afstand per rit (gemiddeld) Reisduur per rit
# Perioden                                    km          Minuten
# 1999                                      3.18            19.02
# 1999                                       3.5            17.29
# 1999                                      1.84            12.41
# 1999                                      2.81            15.61
# 1999                                      4.61            28.74
# ...                                        ...              ...
# 2019                                      4.04            18.03
# 2019                                      2.06            11.91
# 2019                                      3.26            16.69
# 2019                                      5.12            31.04
# 2019                                      2.29            12.67
#
#                                           Lopen  \
#          Ritten per persoon per dag (gemiddeld)
# Perioden                                 aantal
# 1999                                       0.65
# 1999                                       0.05
# 1999                                       0.16
# 1999                                       0.08
# 1999                                       0.27
# ...                                         ...
# 2019                                       0.07
# 2019                                       0.12
# 2019                                       0.06
# 2019                                       0.27
# 2019                                       0.06
#
#                                                                  \
#          Afgelegde afstand per rit (gemiddeld) Reisduur per rit
# Perioden                                    km          Minuten
# 1999                                       1.3            20.87
# 1999                                      0.89            10.52
# 1999                                      0.89            13.36
# 1999                                      0.71             9.97
# 1999                                      1.93            33.08
# ...                                        ...              ...
# 2019                                      0.79             9.69
# 2019                                       0.8            11.59
# 2019                                      0.67             8.39
# 2019                                      2.31            33.87
# 2019                                      0.77            10.05
#
#                            Overige vervoerwijze  \
#          Ritten per persoon per dag (gemiddeld)
# Perioden                                 aantal
# 1999                                       0.12
# 1999                                       0.05
# 1999                                       0.01
# 1999                                       0.01
# 1999                                       0.03
# ...                                         ...
# 2019                                       0.04
# 2019                                       0.01
# 2019                                       0.01
# 2019                                       0.03
# 2019                                       0.01
#
#
#          Afgelegde afstand per rit (gemiddeld) Reisduur per rit
# Perioden                                    km          Minuten
# 1999                                     17.13            32.31
# 1999                                     17.77            27.97
# 1999                                      6.61            16.83
# 1999                                      9.96            28.17
# 1999                                     16.92            45.59
# ...                                        ...              ...
# 2019                                     21.54            29.36
# 2019                                      5.61            15.99
# 2019                                     11.64            27.59
# 2019                                     19.79            45.64
# 2019                                     17.78            29.11
#
# [126 rows x 25 columns]

# %%
totaal = data.iloc[:,[0, 1, 2, 3]]
Bestuurder = data.iloc[:,[0, 4, 5, 6]]
Passagier = data.iloc[:,[0, 7, 8, 9]]
Trein = data.iloc[:,[0, 10, 11, 12]]
BTM = data.iloc[:,[0, 13, 14, 15]]
Fiets = data.iloc[:,[0, 16, 17, 18]]
Lopen = data.iloc[:,[0, 19, 20, 21]]
Overige = data.iloc[:,[0, 22, 23, 24]]

# Create a list of the datasets you want to process
datasets = [totaal, Bestuurder, Passagier, Trein, BTM, Fiets, Lopen, Overige]

# Iterate over each dataset
for df in datasets:
    # Drop the first two levels of the column index (if applicable)
    df.columns = df.columns.droplevel([0, 1])
    
    # Convert relevant columns to numeric, handling errors
    df['aantal'] = pd.to_numeric(df['aantal'], errors='coerce')
    df['km'] = pd.to_numeric(df['km'], errors='coerce')
    df['Minuten'] = pd.to_numeric(df['Minuten'], errors='coerce')
    
    # Calculate 'snelheid' (speed) by dividing distance by time in hours
    df['snelheid'] = df['km'] / (df['Minuten'] / 60)
    
display(Fiets)
# Out:
# C:\Users\vande\AppData\Local\Temp/ipykernel_19140/546960807.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['aantal'] = pd.to_numeric(df['aantal'], errors='coerce')
# C:\Users\vande\AppData\Local\Temp/ipykernel_19140/546960807.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['km'] = pd.to_numeric(df['km'], errors='coerce')
# C:\Users\vande\AppData\Local\Temp/ipykernel_19140/546960807.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Minuten'] = pd.to_numeric(df['Minuten'], errors='coerce')
# C:\Users\vande\AppData\Local\Temp/ipykernel_19140/546960807.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['snelheid'] = df['km'] / (df['Minuten'] / 60)
# Perioden                            Reismotieven  aantal    km  Minuten  \
# 1999                                      Totaal    0.87  3.18    19.02
# 1999                        Van en naar het werk    0.15  3.50    17.29
# 1999                 Winkelen. boodschappen doen    0.20  1.84    12.41
# 1999      Onderwijs volgen. cursus. kinderopvang    0.12  2.81    15.61
# 1999                                  Vrije tijd    0.27  4.61    28.74
# ...                                          ...     ...   ...      ...
# 2019                        Van en naar het werk    0.16  4.04    18.03
# 2019                 Winkelen. boodschappen doen    0.16  2.06    11.91
# 2019      Onderwijs volgen. cursus. kinderopvang    0.13  3.26    16.69
# 2019                                  Vrije tijd    0.27  5.12    31.04
# 2019                        Overige reismotieven    0.10  2.29    12.67
#
# Perioden   snelheid
# 1999      10.031546
# 1999      12.145749
# 1999       8.896052
# 1999      10.800769
# 1999       9.624217
# ...             ...
# 2019      13.444260
# 2019      10.377834
# 2019      11.719593
# 2019       9.896907
# 2019      10.844515
#
# [126 rows x 5 columns]

# %%
display(totaal)
# Out:
# Perioden                            Reismotieven  aantal     km  Minuten  \
# 1999                                      Totaal    3.41  10.96    23.72
# 1999                        Van en naar het werk    0.59  14.78    24.83
# 1999                 Winkelen. boodschappen doen    0.73   4.96    14.97
# 1999      Onderwijs volgen. cursus. kinderopvang    0.30   6.85    17.64
# 1999                                  Vrije tijd    1.19  12.42    31.37
# ...                                          ...     ...    ...      ...
# 2019                        Van en naar het werk    0.61  16.13    24.83
# 2019                 Winkelen. boodschappen doen    0.57   5.36    14.35
# 2019      Onderwijs volgen. cursus. kinderopvang    0.28   7.28    18.58
# 2019                                  Vrije tijd    1.05  13.50    32.59
# 2019                        Overige reismotieven    0.45  11.87    19.57
#
# Perioden   snelheid
# 1999      27.723440
# 1999      35.714861
# 1999      19.879760
# 1999      23.299320
# 1999      23.755180
# ...             ...
# 2019      38.977044
# 2019      22.411150
# 2019      23.509150
# 2019      24.854250
# 2019      36.392437
#
# [126 rows x 5 columns]

# %%
# totalen_totaal = totaal[totaal['Reismotieven'] == 'Totaal']
# display(totalen_totaal)
# totalen_totaal['snelheid'].plot()

dataset_names = ['totaal', 'Bestuurder', 'Passagier', 'Trein', 'BTM', 'Fiets', 'Lopen', 'Overige']
plt.figure(figsize=(15, 10))

for i in range(len(datasets)):
    df_name = f"{dataset_names[i]}_totaal"
    naam = f"{dataset_names[i]}_totaal"
    df_name = datasets[i][datasets[i]['Reismotieven'] == 'Totaal']
    df_name['snelheid'].plot(label=naam)
    plt.legend()
